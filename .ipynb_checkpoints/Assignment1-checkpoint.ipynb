# %% [markdown]
# # 1) Check Present Working Directory

# %%
pwd
# Out:
# 'C:\\Users\\mkrijal\\Desktop\\Assignment1'

# %% [markdown]
# # 2) Import the necessary libraries

# %%
import pandas as pd
import numpy as np
import csv

# %% [markdown]
# # 3) Import dataset and call the dataframe as telco

# %%
telco = pd.read_csv('C://Users/mkrijal/Desktop/Assignment1/Telco-Customer-Churn.csv')
telco.head()
# Out:
#    customerID  gender  SeniorCitizen Partner Dependents  tenure PhoneService  \
# 0  7590-VHVEG  Female              0     Yes         No       1           No
# 1  5575-GNVDE    Male              0      No         No      34          Yes
# 2  3668-QPYBK    Male              0      No         No       2          Yes
# 3  7795-CFOCW    Male              0      No         No      45           No
# 4  9237-HQITU  Female              0      No         No       2          Yes
#
#       MultipleLines InternetService OnlineSecurity  ...  DeviceProtection  \
# 0  No phone service             DSL             No  ...                No
# 1                No             DSL            Yes  ...               Yes
# 2                No             DSL            Yes  ...                No
# 3  No phone service             DSL            Yes  ...               Yes
# 4                No     Fiber optic             No  ...                No
#
#   TechSupport StreamingTV StreamingMovies        Contract PaperlessBilling  \
# 0          No          No              No  Month-to-month              Yes
# 1          No          No              No        One year               No
# 2          No          No              No  Month-to-month              Yes
# 3         Yes          No              No        One year               No
# 4          No          No              No  Month-to-month              Yes
#
#                PaymentMethod MonthlyCharges  TotalCharges Churn
# 0           Electronic check          29.85         29.85    No
# 1               Mailed check          56.95        1889.5    No
# 2               Mailed check          53.85        108.15   Yes
# 3  Bank transfer (automatic)          42.30       1840.75    No
# 4           Electronic check          70.70        151.65   Yes
#
# [5 rows x 21 columns]

# %% [markdown]
# # 4) See the first 10 columns and 10 rows

# %%
telco.ix[0:10, 0:10]
# Out:
#     customerID  gender  SeniorCitizen Partner Dependents  tenure PhoneService  \
# 0   7590-VHVEG  Female              0     Yes         No       1           No
# 1   5575-GNVDE    Male              0      No         No      34          Yes
# 2   3668-QPYBK    Male              0      No         No       2          Yes
# 3   7795-CFOCW    Male              0      No         No      45           No
# 4   9237-HQITU  Female              0      No         No       2          Yes
# 5   9305-CDSKC  Female              0      No         No       8          Yes
# 6   1452-KIOVK    Male              0      No        Yes      22          Yes
# 7   6713-OKOMC  Female              0      No         No      10           No
# 8   7892-POOKP  Female              0     Yes         No      28          Yes
# 9   6388-TABGU    Male              0      No        Yes      62          Yes
# 10  9763-GRSKD    Male              0     Yes        Yes      13          Yes
#
#        MultipleLines InternetService OnlineSecurity
# 0   No phone service             DSL             No
# 1                 No             DSL            Yes
# 2                 No             DSL            Yes
# 3   No phone service             DSL            Yes
# 4                 No     Fiber optic             No
# 5                Yes     Fiber optic             No
# 6                Yes     Fiber optic             No
# 7   No phone service             DSL            Yes
# 8                Yes     Fiber optic             No
# 9                 No             DSL            Yes
# 10                No             DSL            Yes

# %% [markdown]
# # 5) Total number of observations

# %%
len(telco.index)
# Out:
# 7043

# %% [markdown]
# # 6) Show all the columns name

# %%
telco.columns
# Out:
# Index(['customerID', 'gender', 'SeniorCitizen', 'Partner', 'Dependents',
#        'tenure', 'PhoneService', 'MultipleLines', 'InternetService',
#        'OnlineSecurity', 'OnlineBackup', 'DeviceProtection', 'TechSupport',
#        'StreamingTV', 'StreamingMovies', 'Contract', 'PaperlessBilling',
#        'PaymentMethod', 'MonthlyCharges', 'TotalCharges', 'Churn'],
#       dtype='object')

# %% [markdown]
# # 7) Type of column 'Churn'

# %%
telco.dtypes['Churn']
# Out:
# dtype('O')

# %% [markdown]
# # 8) View only the column 'gender', 'SeniorCitizen' and 'Partner'

# %%
telco[['gender', 'SeniorCitizen', 'Partner']]
# Out:
#       gender  SeniorCitizen Partner
# 0     Female              0     Yes
# 1       Male              0      No
# 2       Male              0      No
# 3       Male              0      No
# 4     Female              0      No
# 5     Female              0      No
# 6       Male              0      No
# 7     Female              0      No
# 8     Female              0     Yes
# 9       Male              0      No
# 10      Male              0     Yes
# 11      Male              0      No
# 12      Male              0     Yes
# 13      Male              0      No
# 14      Male              0      No
# 15    Female              0     Yes
# 16    Female              0      No
# 17      Male              0      No
# 18    Female              0     Yes
# 19    Female              0      No
# 20      Male              1      No
# 21      Male              0     Yes
# 22      Male              0      No
# 23    Female              0     Yes
# 24      Male              0     Yes
# 25    Female              0      No
# 26      Male              0     Yes
# 27      Male              0     Yes
# 28      Male              0     Yes
# 29    Female              0      No
# ...      ...            ...     ...
# 7013  Female              0      No
# 7014    Male              0      No
# 7015    Male              1     Yes
# 7016  Female              0      No
# 7017  Female              0      No
# 7018    Male              0     Yes
# 7019  Female              0      No
# 7020    Male              0     Yes
# 7021    Male              0      No
# 7022    Male              0      No
# 7023  Female              1     Yes
# 7024    Male              0     Yes
# 7025  Female              0      No
# 7026  Female              0      No
# 7027    Male              0      No
# 7028  Female              0     Yes
# 7029  Female              1      No
# 7030  Female              0      No
# 7031    Male              1     Yes
# 7032    Male              1      No
# 7033    Male              0      No
# 7034  Female              0      No
# 7035    Male              0      No
# 7036  Female              0      No
# 7037  Female              0      No
# 7038    Male              0     Yes
# 7039  Female              0     Yes
# 7040  Female              0     Yes
# 7041    Male              1     Yes
# 7042    Male              0      No
#
# [7043 rows x 3 columns]

# %% [markdown]
# # 9)Total number of customer based on Internet Service

# %%
telco.groupby(['InternetService']).size()
# Out:
# InternetService
# DSL            2421
# Fiber optic    3096
# No             1526
# dtype: int64

# %% [markdown]
# # 10)Total number of customer based on internet service group by gender

# %%
telco.groupby(['InternetService', 'gender']).size().unstack()
# Out:
# gender           Female  Male
# InternetService
# DSL                1188  1233
# Fiber optic        1553  1543
# No                  747   779

# %% [markdown]
# # 11) Percentage of customer based on internet service and gender

# %%
grouped = telco.groupby(['InternetService','gender'])
s = grouped.size() * 100 / telco.shape[0]
s.unstack()
# Out:
# gender              Female       Male
# InternetService
# DSL              16.867812  17.506744
# Fiber optic      22.050263  21.908278
# No               10.606276  11.060628

# %% [markdown]
# # 12) Select first 5 customer that use fiber optic as internet service

# %%
fiber_optic = telco[telco['InternetService'].isin(['Fiber optic'])]
fiber_optic[0:5]
# Out:
#     customerID  gender  SeniorCitizen Partner Dependents  tenure PhoneService  \
# 4   9237-HQITU  Female              0      No         No       2          Yes
# 5   9305-CDSKC  Female              0      No         No       8          Yes
# 6   1452-KIOVK    Male              0      No        Yes      22          Yes
# 8   7892-POOKP  Female              0     Yes         No      28          Yes
# 12  8091-TTVAX    Male              0     Yes         No      58          Yes
#
#    MultipleLines InternetService OnlineSecurity  ...  DeviceProtection  \
# 4             No     Fiber optic             No  ...                No
# 5            Yes     Fiber optic             No  ...               Yes
# 6            Yes     Fiber optic             No  ...                No
# 8            Yes     Fiber optic             No  ...               Yes
# 12           Yes     Fiber optic             No  ...               Yes
#
#    TechSupport StreamingTV StreamingMovies        Contract PaperlessBilling  \
# 4           No          No              No  Month-to-month              Yes
# 5           No         Yes             Yes  Month-to-month              Yes
# 6           No         Yes              No  Month-to-month              Yes
# 8          Yes         Yes             Yes  Month-to-month              Yes
# 12          No         Yes             Yes        One year               No
#
#               PaymentMethod MonthlyCharges  TotalCharges Churn
# 4          Electronic check          70.70        151.65   Yes
# 5          Electronic check          99.65         820.5   Yes
# 6   Credit card (automatic)          89.10        1949.4    No
# 8          Electronic check         104.80       3046.05   Yes
# 12  Credit card (automatic)         100.35        5681.1    No
#
# [5 rows x 21 columns]

# %% [markdown]
# # 13) Mean of monthly charges based on gender

# %%
telco['MonthlyCharges'].groupby(telco['gender']).mean()
# Out:
# gender
# Female    65.204243
# Male      64.327482
# Name: MonthlyCharges, dtype: float64

# %% [markdown]
# # 14) No of customer that choose paperless billing and grouped by gender

# %%
Paperless = telco[telco['PaperlessBilling'] == 'Yes']
Paperless.groupby('gender').size()
# Out:
# gender
# Female    2086
# Male      2085
# dtype: int64

# %% [markdown]
# # 15) No of customer that churn while holding 1 year contract

# %%
first_year = telco[telco['Contract'].isin(['One year']) & telco['Churn'].isin(['Yes'])]
len(first_year)
# Out:
# 166

# %% [markdown]
# # 16) List of churn customer with  monthly charges more than RM100 and use fiber optic as internet service

# %%
#Churn customer
c_Cust = telco[telco['Churn'].isin(['Yes']) & telco['InternetService'].isin(['Fiber optic'])]

#churn male customer with monthly charges more than RM100
c_Cust[c_Cust['MonthlyCharges']> 100]
# Out:
#       customerID  gender  SeniorCitizen Partner Dependents  tenure  \
# 8     7892-POOKP  Female              0     Yes         No      28
# 13    0280-XJGEX    Male              0      No         No      49
# 38    5380-WJKOV    Male              0      No         No      34
# 104   3192-NQECA    Male              0     Yes         No      68
# 117   5299-RULOA  Female              0     Yes        Yes      10
# 171   1875-QIVME  Female              0     Yes         No       2
# 208   7825-ECJRF  Female              0      No         No      19
# 261   3606-TWKGI    Male              1      No         No      13
# 276   4484-GLZOU  Female              0     Yes         No      52
# 336   6680-NENYN  Female              0      No         No      43
# 339   1343-EHPYB    Male              0     Yes         No      63
# 377   9601-BRXPO  Female              0     Yes         No      25
# 445   7752-XUSCI  Female              0      No         No      60
# 462   0880-TKATG    Male              0     Yes        Yes       4
# 515   9412-GHEEC    Male              0      No         No      40
# 524   8397-MVTAZ    Male              0     Yes         No      34
# 568   0939-YAPAF  Female              0      No         No      35
# 573   4710-FDUIZ    Male              0     Yes         No      56
# 609   3419-SNJJD  Female              1     Yes         No      65
# 630   5099-BAILX    Male              1     Yes        Yes      43
# 635   7207-RMRDB  Female              0     Yes        Yes      65
# 638   4913-EHYUI    Male              1     Yes        Yes      56
# 785   0691-IFBQW  Female              1      No         No      46
# 808   4289-DTDKW    Male              0     Yes         No      40
# 810   2239-JALAW    Male              0      No         No      58
# 811   4853-RULSV    Male              0      No         No      70
# 818   0115-TFERT    Male              0     Yes         No      21
# 830   9101-BWFSS  Female              0     Yes         No      50
# 855   2382-BCKQJ  Female              0      No        Yes      62
# 876   0207-MDKNV  Female              0      No         No      15
# ...          ...     ...            ...     ...        ...     ...
# 6453  8634-MPHTR    Male              1     Yes         No      47
# 6460  8761-NSOBC    Male              0      No         No      44
# 6482  5419-JPRRN    Male              0      No         No       1
# 6496  2474-BRUCM    Male              1     Yes         No      40
# 6526  3190-XFANI    Male              0      No        Yes      49
# 6535  0520-FDVVT    Male              0      No         No      35
# 6537  1444-VVSGW    Male              0     Yes         No      70
# 6544  6661-HBGWL  Female              1      No         No      42
# 6550  1309-BXVOQ    Male              0     Yes         No      21
# 6562  3621-CEOVK  Female              1     Yes         No      14
# 6605  7632-MNYOY    Male              1      No         No      66
# 6606  6518-LGAOV  Female              0     Yes         No      38
# 6616  9600-NAXZN    Male              0      No         No      43
# 6634  1465-VINDH  Female              0     Yes        Yes      10
# 6717  3768-NLUBH    Male              1     Yes         No      57
# 6745  5515-AKOAJ  Female              0      No         No      54
# 6785  3090-HAWSU    Male              0      No         No      61
# 6800  1113-IUJYX  Female              0     Yes         No      14
# 6839  4078-SAYYN  Female              0      No         No      11
# 6853  9079-YEXQJ  Female              0      No         No      54
# 6860  0402-CQAJN  Female              0      No         No      37
# 6886  7234-FECYN  Female              1      No         No       8
# 6894  1400-MMYXY    Male              1     Yes         No       3
# 6914  7142-HVGBG    Male              1     Yes         No      43
# 6918  8267-ZNYVZ  Female              0     Yes         No      33
# 6952  6394-MFYNG  Female              0      No         No      48
# 6962  0886-QGENL  Female              1     Yes         No      27
# 6972  6664-FPDAC  Female              1      No         No      56
# 7006  0093-XWZFY    Male              0      No         No      40
# 7034  0639-TSIQW  Female              0      No         No      67
#
#      PhoneService MultipleLines InternetService OnlineSecurity  ...   \
# 8             Yes           Yes     Fiber optic             No  ...
# 13            Yes           Yes     Fiber optic             No  ...
# 38            Yes           Yes     Fiber optic             No  ...
# 104           Yes           Yes     Fiber optic             No  ...
# 117           Yes           Yes     Fiber optic            Yes  ...
# 171           Yes           Yes     Fiber optic             No  ...
# 208           Yes            No     Fiber optic            Yes  ...
# 261           Yes           Yes     Fiber optic             No  ...
# 276           Yes           Yes     Fiber optic             No  ...
# 336           Yes           Yes     Fiber optic             No  ...
# 339           Yes           Yes     Fiber optic             No  ...
# 377           Yes           Yes     Fiber optic             No  ...
# 445           Yes           Yes     Fiber optic             No  ...
# 462           Yes           Yes     Fiber optic             No  ...
# 515           Yes           Yes     Fiber optic             No  ...
# 524           Yes           Yes     Fiber optic             No  ...
# 568           Yes           Yes     Fiber optic             No  ...
# 573           Yes           Yes     Fiber optic             No  ...
# 609           Yes           Yes     Fiber optic            Yes  ...
# 630           Yes           Yes     Fiber optic             No  ...
# 635           Yes           Yes     Fiber optic             No  ...
# 638           Yes           Yes     Fiber optic            Yes  ...
# 785           Yes           Yes     Fiber optic            Yes  ...
# 808           Yes           Yes     Fiber optic             No  ...
# 810           Yes           Yes     Fiber optic             No  ...
# 811           Yes           Yes     Fiber optic            Yes  ...
# 818           Yes           Yes     Fiber optic             No  ...
# 830           Yes           Yes     Fiber optic            Yes  ...
# 855           Yes           Yes     Fiber optic             No  ...
# 876           Yes            No     Fiber optic            Yes  ...
# ...           ...           ...             ...            ...  ...
# 6453          Yes           Yes     Fiber optic             No  ...
# 6460          Yes            No     Fiber optic             No  ...
# 6482          Yes           Yes     Fiber optic             No  ...
# 6496          Yes           Yes     Fiber optic            Yes  ...
# 6526          Yes           Yes     Fiber optic             No  ...
# 6535          Yes            No     Fiber optic             No  ...
# 6537          Yes           Yes     Fiber optic            Yes  ...
# 6544          Yes           Yes     Fiber optic             No  ...
# 6550          Yes           Yes     Fiber optic             No  ...
# 6562          Yes           Yes     Fiber optic             No  ...
# 6605          Yes           Yes     Fiber optic             No  ...
# 6606          Yes           Yes     Fiber optic             No  ...
# 6616          Yes           Yes     Fiber optic             No  ...
# 6634          Yes           Yes     Fiber optic             No  ...
# 6717          Yes           Yes     Fiber optic             No  ...
# 6745          Yes           Yes     Fiber optic             No  ...
# 6785          Yes           Yes     Fiber optic            Yes  ...
# 6800          Yes            No     Fiber optic            Yes  ...
# 6839          Yes           Yes     Fiber optic             No  ...
# 6853          Yes           Yes     Fiber optic             No  ...
# 6860          Yes           Yes     Fiber optic             No  ...
# 6886          Yes           Yes     Fiber optic             No  ...
# 6894          Yes           Yes     Fiber optic             No  ...
# 6914          Yes           Yes     Fiber optic             No  ...
# 6918          Yes            No     Fiber optic            Yes  ...
# 6952          Yes           Yes     Fiber optic             No  ...
# 6962          Yes            No     Fiber optic            Yes  ...
# 6972          Yes           Yes     Fiber optic             No  ...
# 7006          Yes           Yes     Fiber optic             No  ...
# 7034          Yes           Yes     Fiber optic            Yes  ...
#
#      DeviceProtection TechSupport StreamingTV StreamingMovies        Contract  \
# 8                 Yes         Yes         Yes             Yes  Month-to-month
# 13                Yes          No         Yes             Yes  Month-to-month
# 38                Yes          No         Yes             Yes  Month-to-month
# 104               Yes         Yes         Yes             Yes        Two year
# 117                No          No         Yes             Yes  Month-to-month
# 171               Yes         Yes         Yes             Yes  Month-to-month
# 208               Yes         Yes         Yes             Yes  Month-to-month
# 261               Yes          No         Yes             Yes  Month-to-month
# 276               Yes          No         Yes             Yes  Month-to-month
# 336               Yes          No         Yes             Yes        Two year
# 339               Yes          No         Yes             Yes  Month-to-month
# 377               Yes         Yes         Yes             Yes  Month-to-month
# 445               Yes          No         Yes             Yes  Month-to-month
# 462               Yes          No         Yes             Yes  Month-to-month
# 515               Yes         Yes         Yes             Yes  Month-to-month
# 524               Yes          No         Yes             Yes  Month-to-month
# 568               Yes          No         Yes             Yes  Month-to-month
# 573                No          No         Yes             Yes        One year
# 609               Yes          No         Yes             Yes  Month-to-month
# 630               Yes         Yes         Yes             Yes  Month-to-month
# 635               Yes          No         Yes             Yes  Month-to-month
# 638               Yes          No         Yes             Yes        One year
# 785               Yes          No         Yes             Yes        One year
# 808                No          No         Yes             Yes  Month-to-month
# 810               Yes          No         Yes             Yes        One year
# 811                No         Yes         Yes             Yes        Two year
# 818               Yes         Yes         Yes             Yes  Month-to-month
# 830                No         Yes         Yes             Yes        One year
# 855               Yes          No         Yes             Yes        One year
# 876               Yes         Yes         Yes             Yes  Month-to-month
# ...               ...         ...         ...             ...             ...
# 6453              Yes          No         Yes             Yes  Month-to-month
# 6460               No         Yes         Yes             Yes  Month-to-month
# 6482              Yes          No         Yes             Yes  Month-to-month
# 6496               No          No         Yes             Yes  Month-to-month
# 6526               No         Yes         Yes             Yes        One year
# 6535              Yes          No         Yes             Yes        One year
# 6537              Yes         Yes         Yes             Yes        One year
# 6544              Yes          No         Yes             Yes  Month-to-month
# 6550              Yes         Yes         Yes             Yes  Month-to-month
# 6562               No          No         Yes             Yes  Month-to-month
# 6605              Yes         Yes         Yes             Yes        One year
# 6606              Yes         Yes         Yes             Yes  Month-to-month
# 6616               No          No         Yes             Yes  Month-to-month
# 6634              Yes          No         Yes             Yes  Month-to-month
# 6717              Yes          No         Yes             Yes  Month-to-month
# 6745               No         Yes         Yes             Yes  Month-to-month
# 6785              Yes         Yes         Yes             Yes        Two year
# 6800               No         Yes         Yes             Yes        One year
# 6839              Yes          No         Yes             Yes  Month-to-month
# 6853              Yes         Yes         Yes             Yes  Month-to-month
# 6860              Yes          No         Yes             Yes  Month-to-month
# 6886              Yes          No         Yes             Yes  Month-to-month
# 6894              Yes          No         Yes             Yes  Month-to-month
# 6914              Yes          No         Yes             Yes  Month-to-month
# 6918              Yes         Yes         Yes             Yes        One year
# 6952              Yes          No         Yes             Yes  Month-to-month
# 6962              Yes          No         Yes             Yes  Month-to-month
# 6972              Yes         Yes         Yes             Yes        One year
# 7006              Yes          No         Yes             Yes  Month-to-month
# 7034              Yes          No         Yes              No  Month-to-month
#
#      PaperlessBilling              PaymentMethod MonthlyCharges  TotalCharges  \
# 8                 Yes           Electronic check         104.80       3046.05
# 13                Yes  Bank transfer (automatic)         103.70        5036.3
# 38                Yes           Electronic check         106.35       3549.25
# 104               Yes  Bank transfer (automatic)         110.00       7611.85
# 117               Yes           Electronic check         100.25       1064.65
# 171               Yes           Electronic check         104.40         242.8
# 208               Yes           Electronic check         106.60       1934.45
# 261               Yes           Electronic check         106.90        1364.3
# 276               Yes           Electronic check         105.05       5624.85
# 336               Yes           Electronic check         104.60       4759.85
# 339               Yes           Electronic check         103.40          6603
# 377               Yes  Bank transfer (automatic)         104.95        2566.5
# 445               Yes           Electronic check         105.90       6396.45
# 462                No           Electronic check         101.15         385.9
# 515                No  Bank transfer (automatic)         104.80       4131.95
# 524               Yes           Electronic check         100.05          3480
# 568               Yes           Electronic check         100.25        3527.6
# 573                No    Credit card (automatic)         100.30       5614.45
# 609                No  Bank transfer (automatic)         105.25        6786.4
# 630               Yes  Bank transfer (automatic)         110.75        4687.9
# 635               Yes           Electronic check         105.50       6985.65
# 638               Yes  Bank transfer (automatic)         104.55       5794.65
# 785               Yes           Electronic check         110.00        4874.8
# 808               Yes           Electronic check         101.30        4113.1
# 810               Yes  Bank transfer (automatic)         103.25       6017.65
# 811               Yes    Credit card (automatic)         104.00       7250.15
# 818               Yes           Electronic check         111.20        2317.1
# 830                No           Electronic check         108.55        5610.7
# 855               Yes           Electronic check         100.15       6413.65
# 876                No           Electronic check         105.10       1582.75
# ...               ...                        ...            ...           ...
# 6453              Yes           Electronic check         100.05       4871.05
# 6460               No           Electronic check         100.55       4398.15
# 6482              Yes           Electronic check         101.45        101.45
# 6496               No           Electronic check         101.85        4086.3
# 6526              Yes  Bank transfer (automatic)         100.60       5069.65
# 6535              Yes  Bank transfer (automatic)         102.35        3626.1
# 6537               No    Credit card (automatic)         115.65       7968.85
# 6544              Yes  Bank transfer (automatic)         104.75       4323.45
# 6550              Yes           Electronic check         106.10       2249.95
# 6562              Yes           Electronic check         100.20        1369.8
# 6605               No    Credit card (automatic)         110.90       7432.05
# 6606              Yes           Electronic check         105.00        4026.4
# 6616              Yes           Electronic check         101.40          4528
# 6634              Yes    Credit card (automatic)         102.10       1068.85
# 6717               No           Electronic check         100.60       5746.15
# 6745              Yes           Electronic check         100.10        5440.9
# 6785              Yes    Credit card (automatic)         111.60       6876.05
# 6800               No               Mailed check         105.95        1348.9
# 6839              Yes           Electronic check         100.75       1129.75
# 6853               No           Electronic check         111.10       6014.85
# 6860              Yes  Bank transfer (automatic)         101.90       3545.35
# 6886               No           Electronic check         101.35         780.5
# 6894              Yes           Electronic check         105.90        334.65
# 6914              Yes           Electronic check         103.00        4414.3
# 6918              Yes           Electronic check         103.75       3361.05
# 6952              Yes  Bank transfer (automatic)         107.40        5121.3
# 6962              Yes           Electronic check         101.25       2754.45
# 6972              Yes           Electronic check         111.95        6418.9
# 7006              Yes    Credit card (automatic)         104.50       4036.85
# 7034              Yes    Credit card (automatic)         102.95       6886.25
#
#      Churn
# 8      Yes
# 13     Yes
# 38     Yes
# 104    Yes
# 117    Yes
# 171    Yes
# 208    Yes
# 261    Yes
# 276    Yes
# 336    Yes
# 339    Yes
# 377    Yes
# 445    Yes
# 462    Yes
# 515    Yes
# 524    Yes
# 568    Yes
# 573    Yes
# 609    Yes
# 630    Yes
# 635    Yes
# 638    Yes
# 785    Yes
# 808    Yes
# 810    Yes
# 811    Yes
# 818    Yes
# 830    Yes
# 855    Yes
# 876    Yes
# ...    ...
# 6453   Yes
# 6460   Yes
# 6482   Yes
# 6496   Yes
# 6526   Yes
# 6535   Yes
# 6537   Yes
# 6544   Yes
# 6550   Yes
# 6562   Yes
# 6605   Yes
# 6606   Yes
# 6616   Yes
# 6634   Yes
# 6717   Yes
# 6745   Yes
# 6785   Yes
# 6800   Yes
# 6839   Yes
# 6853   Yes
# 6860   Yes
# 6886   Yes
# 6894   Yes
# 6914   Yes
# 6918   Yes
# 6952   Yes
# 6962   Yes
# 6972   Yes
# 7006   Yes
# 7034   Yes
#
# [253 rows x 21 columns]

# %% [markdown]
# # 17) Total number by gender and internet service the customer that pay more than 80 monthly charges

# %%
Rich_cust = telco[telco['MonthlyCharges']> 80]
Rich_cust.groupby(['InternetService', 'gender']).size().unstack()
# Out:
# gender           Female  Male
# InternetService
# DSL                 145   131
# Fiber optic        1189  1201

# %% [markdown]
# # 18) Total number of customer that pay more than 80 for monthly charges tenure less than 10 and churn. Group by internet service and gender

# %%
OR_cust = Rich_cust[(Rich_cust['tenure']<10) & (Rich_cust['Churn'].isin(['Yes']))]
OR_cust.groupby(['InternetService','gender' ]).size().unstack()
# Out:
# gender           Female  Male
# InternetService
# Fiber optic         147   131
