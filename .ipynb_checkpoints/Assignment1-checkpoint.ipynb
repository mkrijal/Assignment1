# %% [markdown]
# # 1) Check Present Working Directory

# %%
pwd
# Out:
# 'C:\\Users\\mkrijal\\Desktop\\Assignment1'

# %% [markdown]
# # 2) Import the necessary libraries

# %%
import pandas as pd
import numpy as np
import csv

# %% [markdown]
# # 3) Import dataset and call the dataframe as telco

# %%
telco = pd.read_csv('C://Users/mkrijal/Desktop/Assignment1/Telco-Customer-Churn.csv')
telco.head()
# Out:
#    customerID  gender  SeniorCitizen Partner Dependents  tenure PhoneService  \
# 0  7590-VHVEG  Female              0     Yes         No       1           No
# 1  5575-GNVDE    Male              0      No         No      34          Yes
# 2  3668-QPYBK    Male              0      No         No       2          Yes
# 3  7795-CFOCW    Male              0      No         No      45           No
# 4  9237-HQITU  Female              0      No         No       2          Yes
#
#       MultipleLines InternetService OnlineSecurity  ...  DeviceProtection  \
# 0  No phone service             DSL             No  ...                No
# 1                No             DSL            Yes  ...               Yes
# 2                No             DSL            Yes  ...                No
# 3  No phone service             DSL            Yes  ...               Yes
# 4                No     Fiber optic             No  ...                No
#
# ...

# %% [markdown]
# # 4) See the first 10 columns and 10 rows

# %%
telco.ix[0:10, 0:10]
# Out:
#     customerID  gender  SeniorCitizen Partner Dependents  tenure PhoneService  \
# 0   7590-VHVEG  Female              0     Yes         No       1           No
# 1   5575-GNVDE    Male              0      No         No      34          Yes
# 2   3668-QPYBK    Male              0      No         No       2          Yes
# 3   7795-CFOCW    Male              0      No         No      45           No
# 4   9237-HQITU  Female              0      No         No       2          Yes
# 5   9305-CDSKC  Female              0      No         No       8          Yes
# 6   1452-KIOVK    Male              0      No        Yes      22          Yes
# 7   6713-OKOMC  Female              0      No         No      10           No
# 8   7892-POOKP  Female              0     Yes         No      28          Yes
# 9   6388-TABGU    Male              0      No        Yes      62          Yes
# 10  9763-GRSKD    Male              0     Yes        Yes      13          Yes
#
# ...

# %% [markdown]
# # 5) Total number of observations

# %%
len(telco.index)
# Out:
# 7043

# %% [markdown]
# # 6) Show all the columns name

# %%
telco.columns
# Out:
# Index(['customerID', 'gender', 'SeniorCitizen', 'Partner', 'Dependents',
#        'tenure', 'PhoneService', 'MultipleLines', 'InternetService',
#        'OnlineSecurity', 'OnlineBackup', 'DeviceProtection', 'TechSupport',
#        'StreamingTV', 'StreamingMovies', 'Contract', 'PaperlessBilling',
#        'PaymentMethod', 'MonthlyCharges', 'TotalCharges', 'Churn'],
#       dtype='object')

# %% [markdown]
# # 7) Type of column 'Churn'

# %%
telco.dtypes['Churn']
# Out:
# dtype('O')

# %% [markdown]
# # 8) View the column 'gender', 'SeniorCitizen' and 'Partner' only

# %%
telco[['gender', 'SeniorCitizen', 'Partner']]
# Out:
#       gender  SeniorCitizen Partner
# 0     Female              0     Yes
# 1       Male              0      No
# 2       Male              0      No
# 3       Male              0      No
# 4     Female              0      No
# 5     Female              0      No
# 6       Male              0      No
# 7     Female              0      No
# 8     Female              0     Yes
# 9       Male              0      No
# 10      Male              0     Yes
# 11      Male              0      No
# 12      Male              0     Yes
# 13      Male              0      No
# 14      Male              0      No
# 15    Female              0     Yes
# 16    Female              0      No
# 17      Male              0      No
# 18    Female              0     Yes
# 19    Female              0      No
# 20      Male              1      No
# 21      Male              0     Yes
# 22      Male              0      No
# 23    Female              0     Yes
# 24      Male              0     Yes
# ...

# %% [markdown]
# # 9)Total number of customer based on Internet Service

# %%
telco.groupby(['InternetService']).size()
# Out:
# InternetService
# DSL            2421
# Fiber optic    3096
# No             1526
# dtype: int64

# %% [markdown]
# # 10)Total number of customer based on internet service group by gender

# %%
telco.groupby(['InternetService', 'gender']).size().unstack()
# Out:
# gender           Female  Male
# InternetService
# DSL                1188  1233
# Fiber optic        1553  1543
# No                  747   779

# %% [markdown]
# # 11) Percentage of customer based on internet service and gender

# %%
grouped = telco.groupby(['InternetService','gender'])
s = grouped.size() * 100 / telco.shape[0]
s.unstack()
# Out:
# gender              Female       Male
# InternetService
# DSL              16.867812  17.506744
# Fiber optic      22.050263  21.908278
# No               10.606276  11.060628

# %% [markdown]
# # 12) Select first 5 customer that use fiber optic as internet service

# %%
fiber_optic = telco[telco['InternetService'].isin(['Fiber optic'])]
fiber_optic[0:5]
# Out:
#     customerID  gender  SeniorCitizen Partner Dependents  tenure PhoneService  \
# 4   9237-HQITU  Female              0      No         No       2          Yes
# 5   9305-CDSKC  Female              0      No         No       8          Yes
# 6   1452-KIOVK    Male              0      No        Yes      22          Yes
# 8   7892-POOKP  Female              0     Yes         No      28          Yes
# 12  8091-TTVAX    Male              0     Yes         No      58          Yes
#
#    MultipleLines InternetService OnlineSecurity  ...  DeviceProtection  \
# 4             No     Fiber optic             No  ...                No
# 5            Yes     Fiber optic             No  ...               Yes
# 6            Yes     Fiber optic             No  ...                No
# 8            Yes     Fiber optic             No  ...               Yes
# 12           Yes     Fiber optic             No  ...               Yes
#
# ...

# %% [markdown]
# # 13) Mean of monthly charges based on gender

# %%
telco['MonthlyCharges'].groupby(telco['gender']).mean()
# Out:
# gender
# Female    65.204243
# Male      64.327482
# Name: MonthlyCharges, dtype: float64

# %% [markdown]
# # 14) No of customer that choose paperless billing and grouped by gender

# %%
Paperless = telco[telco['PaperlessBilling'] == 'Yes']
Paperless.groupby('gender').size()
# Out:
# gender
# Female    2086
# Male      2085
# dtype: int64

# %% [markdown]
# # 15) No of customer that churn while holding 1 year contract

# %%
first_year = telco[telco['Contract'].isin(['One year']) & telco['Churn'].isin(['Yes'])]
len(first_year)
# Out:
# 166

# %% [markdown]
# # 16) List of churn customer with  monthly charges less than 80 and use fiber optic as internet service

# %%
#Churn customer
c_Cust = telco[(telco['Churn'].isin(['Yes'])) & (telco['InternetService'].isin(['Fiber optic']))]

#churn male customer with monthly charges more than RM80
c_Cust[c_Cust['MonthlyCharges']< 80]
# Out:
#       customerID  gender  SeniorCitizen Partner Dependents  tenure  \
# 4     9237-HQITU  Female              0      No         No       2
# 36    6047-YHPVI    Male              0      No         No       5
# 80    5919-TMRGD  Female              0      No        Yes       1
# 82    9191-MYQKX  Female              0     Yes         No       7
# 95    8637-XJIVR  Female              0      No         No      12
# 113   4846-WHAFZ  Female              1     Yes         No      37
# 122   0404-SWRVG    Male              0      No         No       3
# 126   4412-YLTKF  Female              1      No         No      27
# 139   0390-DCFDQ  Female              1     Yes         No       1
# 166   3376-BMGFE  Female              0      No         No       4
# 176   2656-FMOKZ  Female              1      No         No      15
# 177   2070-FNEXE  Female              1      No         No       7
# 184   1918-ZBFQJ  Female              0      No         No      13
# ...

# %% [markdown]
# # 17) Total number by gender and internet service the customer that pay more than 80 monthly charges

# %%
Rich_cust = telco[telco['MonthlyCharges']> 80]
Rich_cust.groupby(['InternetService', 'gender']).size().unstack()
# Out:
# gender           Female  Male
# InternetService
# DSL                 145   131
# Fiber optic        1189  1201

# %% [markdown]
# # 18) Total number of customer that pay more than 80 for monthly charges tenure less than 10 and churn. Group by internet service and gender

# %%
OR_cust = Rich_cust[(Rich_cust['tenure']<10) & (Rich_cust['Churn'].isin(['Yes']))]
OR_cust.groupby(['InternetService','gender' ]).size().unstack()
# Out:
# gender           Female  Male
# InternetService
# Fiber optic         147   131

# %% [markdown]
# # 19) Min and max monthly charges for customer that has partner group by gender

# %%
#function min and max
def get_stats(group):
    return {'min': group.min(), 'max': group.max()}

#group by gender
custPartner = telco[telco['Partner'].isin(['Yes'])]  #select by partner
custPartner['MonthlyCharges'].groupby(custPartner['gender']).apply(get_stats).unstack()
# Out:
#            max   min
# gender
# Female  118.75  18.4
# Male    117.80  18.8

# %% [markdown]
# # 20) Percentage of senior citizen customer with partner and no partner

# %%
Senior_cust = telco[telco['SeniorCitizen']==1]
grouped = Senior_cust.groupby(['gender','Partner'])
p = grouped.size() * 100 / telco.shape[0]
p.unstack()
# Out:
# Partner        No       Yes
# gender
# Female   4.543518  3.521227
# Male     3.535425  4.614511
